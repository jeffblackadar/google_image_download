# %%
import os
os.chdir('/content/drive/MyDrive/google_image_download/')
# !pwd
#!git init .
# Out:
# /content/drive/MyDrive/google_image_download
# Initialized empty Git repository in /content/drive/MyDrive/google_image_download/.git/

# %%
# !git config --global user.email "jeffblackadar@gmail.com"
# !git config --global user.name "jeffblackadar"

# %%
#https://amitness.com/2020/06/google-colaboratory-tips/
import subprocess
input
print('Enter your pat:')
pat = input()
command = "git remote add origin https://"+pat+"@github.com/jeffblackadar/google_image_download.git"
subprocess.call(command, shell=True)
command = "git remote set-url origin https://"+pat+"@github.com/jeffblackadar/google_image_download.git"
subprocess.call(command, shell=True)
print("delete this output")

# %%
# !git branch -m master main
# Out:
# error: refname refs/heads/master not found
# fatal: Branch rename failed

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/jeffblackadar/google_image_download
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
